# %% [markdown]
# <img src="img/Spotify.jpg" />

# %% [markdown]
# ---

# %% [markdown]
# # <span style='color:green'> **Analyse von Charakteristiken unbeliebter Spotify Songs (Gruppe 07)** </span>

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **1. Kontext** </span>

# %% [markdown]
# * #### <span style='color:green'> **Themenbereich:** </span> Musik
# * #### <span style='color:green'> **Beispiel für Klassifikationsfall:** </span> Klassifizierung negativer Charakteristiken und deren Einfluss auf die Beliebtheit von Spotify Songs.
# * #### <span style='color:green'> **Fragestellung:** </span> Welche Charakteristiken haben den stärksten Einfluss auf die Beliebtheit und sind diese einzelnn identifizierbar oder fordert es eine Kombination an Charakteristiken.
# * #### <span style='color:green'> **Ziel:** </span> Die Analyse soll zeigen, wie ein Song idealerweise NICHT aufgebaut werden soll.

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **2. Explorative Datenanalyse** </span>

# %%
import pandas as pd

spotify = pd.read_csv('Spotify_Daten_2.csv', delimiter=',')
spotify.head(25)
# Out:
#                                          danceability energy  key loudness  \
# 0                                                0.53   0.77    4   -6.633
# 1                                               0.565   0.73    1   -6.063
# 2                                               0.427  0.546    4   -8.727
# 3                                               0.421  0.531    7   -5.516
# 4                                               0.537  0.804    8   -7.378
# 5                                                0.71  0.621    9   -7.879
# 6                                               0.419  0.821   11   -5.768
# 7                                               0.565  0.624    1   -5.718
# 8                                               0.547   0.56    0   -7.187
# 9                                               0.533  0.785    5   -5.466
# 10                                              0.482  0.369    2   -7.637
# ...

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10877 entries, 0 to 10876
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      10877 non-null  object
#  1   energy            10527 non-null  object
#  2   key               10527 non-null  object
#  3   loudness          10527 non-null  object
#  4   mode              10526 non-null  float64
#  5   speechiness       10526 non-null  float64
#  6   acousticness      10526 non-null  float64
#  7   instrumentalness  10526 non-null  float64
#  8   liveness          10526 non-null  float64
#  9   valence           10526 non-null  float64
#  10  tempo             10526 non-null  float64
#  11  duration_ms       10526 non-null  float64
#  12  explicit          10526 non-null  object
#  13  popularity        10526 non-null  float64
#  14  track_name        10526 non-null  object
#  15  track_artist      10526 non-null  object
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **3. Unifying & Transformation** </span>

# %%
cleaned_spotify = spotify.dropna()
cleaned_spotify.head(25)
# Out:
#    danceability energy key loudness  mode  speechiness  acousticness  \
# 0          0.53   0.77   4   -6.633   0.0       0.0389       0.28400
# 1         0.565   0.73   1   -6.063   1.0       0.0730       0.36500
# 2         0.427  0.546   4   -8.727   1.0       0.0849       0.53900
# 3         0.421  0.531   7   -5.516   1.0       0.0262       0.70600
# 4         0.537  0.804   8   -7.378   0.0       0.1570       0.37900
# 5          0.71  0.621   9   -7.879   0.0       0.0329       0.40500
# 6         0.419  0.821  11   -5.768   0.0       0.0431       0.01370
# 7         0.565  0.624   1   -5.718   1.0       0.0351       0.00442
# 8         0.547   0.56   0   -7.187   1.0       0.0510       0.55100
# 9         0.533  0.785   5   -5.466   1.0       0.0481       0.59100
# 10        0.482  0.369   2   -7.637   0.0       0.0412       0.75000
# 11        0.589  0.659   2   -7.491   1.0       0.0516       0.10400
# 12        0.573  0.816   0   -7.263   1.0       0.0419       0.00347
# ...

# %%
cleaned_spotify.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms', 'explicit', 'popularity', 'track_name', 'track_artist',
#        'track_id;'],
#       dtype='object')

# %%
cleaned_spotify.columns = ['Tanzbarkeit', 'Energy', 'Tonlage', 'Lautheit_nach_LUFS', 'Modus', 'Sprachgewandtheit', 'Akustik', 'Instrumentalität', 'Lebhaftigkeit', 'Wertigkeit', 'BPM', 'Länge_in_ms', 'Explicit', 'Popularität', 'Track_Name', 'Interpret', 'Track_Id']
cleaned_spotify.head(5)
# Out:
#   Tanzbarkeit Energy Tonlage Lautheit_nach_LUFS  Modus  Sprachgewandtheit  \
# 0        0.53   0.77       4             -6.633    0.0             0.0389
# 1       0.565   0.73       1             -6.063    1.0             0.0730
# 2       0.427  0.546       4             -8.727    1.0             0.0849
# 3       0.421  0.531       7             -5.516    1.0             0.0262
# 4       0.537  0.804       8             -7.378    0.0             0.1570
#
#    Akustik  Instrumentalität  Lebhaftigkeit  Wertigkeit      BPM  Länge_in_ms  \
# 0    0.284          0.501000          0.744       0.623  120.144     225696.0
# 1    0.365          0.000000          0.237       0.511  130.026     158093.0
# 2    0.539          0.015200          0.368       0.435   78.345     167262.0
# 3    0.706          0.000208          0.110       0.383   85.080     236832.0
# 4    0.379          0.000489          0.323       0.543  139.950     239400.0
#
# ...

# %%
cleaned_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10526 entries, 0 to 10876
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Tanzbarkeit         10526 non-null  object
#  1   Energy              10526 non-null  object
#  2   Tonlage             10526 non-null  object
#  3   Lautheit_nach_LUFS  10526 non-null  object
#  4   Modus               10526 non-null  float64
#  5   Sprachgewandtheit   10526 non-null  float64
#  6   Akustik             10526 non-null  float64
#  7   Instrumentalität    10526 non-null  float64
#  8   Lebhaftigkeit       10526 non-null  float64
#  9   Wertigkeit          10526 non-null  float64
#  10  BPM                 10526 non-null  float64
#  11  Länge_in_ms         10526 non-null  float64
#  12  Explicit            10526 non-null  object
#  13  Popularität         10526 non-null  float64
#  14  Track_Name          10526 non-null  object
# ...

# %%
cleaned_spotify['Tanzbarkeit'] = cleaned_spotify['Tanzbarkeit'].astype('float')
cleaned_spotify.dtypes
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_19276\1147485463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_spotify['Tanzbarkeit'] = cleaned_spotify['Tanzbarkeit'].astype('float')
# Tanzbarkeit           float64
# Energy                 object
# Tonlage                object
# Lautheit_nach_LUFS     object
# Modus                 float64
# Sprachgewandtheit     float64
# Akustik               float64
# Instrumentalität      float64
# Lebhaftigkeit         float64
# Wertigkeit            float64
# BPM                   float64
# Länge_in_ms           float64
# Explicit               object
# Popularität           float64
# Track_Name             object
# Interpret              object
# Track_Id               object
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **4. Data Cleansing** </span>

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **5. Analysis & Validation** </span>

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **6. Feature Selection & Engineering** </span>

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:green'> **7. Anwendung in Machine Learning** </span>
